# %% [markdown]
# # Importing python libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from matplotlib import pyplot

# %% [markdown]
# # Importing the work file

# %%
customers = pd.read_csv("C:/Users/Jarvis/Desktop/mt_data22.csv",encoding= 'unicode_escape')  # importing file

# %%
customers.head(5)   #exploring the variables
# Out:
#    Quartal  Year  Price in /m²  Material Costs  Employment costs  \
# 0        1  2004           1448            76.9              83.2
# 1        2  2004           1433            79.9              83.3
# 2        3  2004           1422            79.9              83.2
# 3        4  2004           1405            79.9              81.3
# 4        1  2005           1395            80.5              83.6
#
#    Inflation Rate  Unemployment rate  Participation at Stock Exchange  \
# 0          0.0055            0.10050                             7843
# 1          0.0055            0.10300                             7843
# 2          0.0011            0.10375                             7843
# 3          0.0099            0.10600                             7843
# 4          0.0012            0.10900                             8066
#
#           GDP   Money Supply   Key interest rate    DAX   \
# 0  9.180000e+11    1.640000e+12             0.0225  4018.51
# 1  8.940000e+11    1.640000e+12             0.0225  3950.01
# 2  9.050000e+11    1.640000e+12             0.0225  3858.88
# 3  9.600000e+11    1.640000e+12             0.0225  4079.26
# 4  1.000000e+12    1.770000e+12             0.0225  4309.37
#
#    Building permits/Inhabitants  Volatility Index
# 0                         47075             22.06
# 1                         67250             23.07
# 2                         73975             19.55
# 3                         80700             16.97
# 4                         42000             13.50

# %%
customers=customers.drop("Quartal",axis=1) #dropping quartals

# %%
customers=customers.drop("Year",axis=1)   #dropping year

# %%
customers.corr()   #correlation matrix
# Out:
#                                  Price in /m²  Material Costs  \
# Price in /m²                         1.000000        0.875576
# Material Costs                        0.875576        1.000000
# Employment costs                      0.942764        0.956856
# Inflation Rate                        0.154877        0.115058
# Unemployment rate                    -0.537589       -0.806323
# Participation at Stock Exchange       0.525073        0.150764
# GDP                                 -0.086939        0.223126
# Money Supply                         0.920573        0.961871
# Key interest rate                    -0.645327       -0.748547
# DAX                                  0.899130        0.924159
# Building permits/Inhabitants          0.721368        0.637347
# Volatility Index                     -0.037554        0.026473
#
#                                  Employment costs  Inflation Rate  \
# Price in /m²                            0.942764        0.154877
# Material Costs                           0.956856        0.115058
# Employment costs                         1.000000        0.087620
# Inflation Rate                           0.087620        1.000000
# Unemployment rate                       -0.756218        0.049967
# Participation at Stock Exchange          0.270191        0.224429
# GDP                                     0.050669        0.037624
# Money Supply                            0.974608        0.092875
# Key interest rate                       -0.798475        0.083853
# DAX                                     0.922070        0.139824
# Building permits/Inhabitants             0.696985       -0.015334
# Volatility Index                         0.031243       -0.208213
#
#                                  Unemployment rate  \
# Price in /m²                            -0.537589
# Material Costs                           -0.806323
# Employment costs                         -0.756218
# Inflation Rate                            0.049967
# Unemployment rate                         1.000000
# Participation at Stock Exchange           0.334668
# GDP                                     -0.262891
# Money Supply                            -0.741107
# Key interest rate                         0.770469
# DAX                                     -0.749628
# Building permits/Inhabitants             -0.506178
# Volatility Index                          0.015277
#
#                                  Participation at Stock Exchange     GDP   \
# Price in /m²                                           0.525073 -0.086939
# Material Costs                                          0.150764  0.223126
# Employment costs                                        0.270191  0.050669
# Inflation Rate                                          0.224429  0.037624
# Unemployment rate                                       0.334668 -0.262891
# Participation at Stock Exchange                         1.000000 -0.285927
# GDP                                                   -0.285927  1.000000
# Money Supply                                           0.282845  0.152948
# Key interest rate                                       0.172670  0.084607
# DAX                                                    0.260585  0.042471
# Building permits/Inhabitants                            0.245573 -0.256043
# Volatility Index                                       -0.003146  0.197078
#
#                                  Money Supply   Key interest rate     DAX   \
# Price in /m²                          0.920573          -0.645327  0.899130
# Material Costs                         0.961871          -0.748547  0.924159
# Employment costs                       0.974608          -0.798475  0.922070
# Inflation Rate                         0.092875           0.083853  0.139824
# Unemployment rate                     -0.741107           0.770469 -0.749628
# Participation at Stock Exchange        0.282845           0.172670  0.260585
# GDP                                   0.152948           0.084607  0.042471
# Money Supply                          1.000000          -0.709335  0.923089
# Key interest rate                     -0.709335           1.000000 -0.695180
# DAX                                   0.923089          -0.695180  1.000000
# Building permits/Inhabitants           0.606029          -0.617343  0.700109
# Volatility Index                       0.115704           0.071489 -0.169176
#
#                                  Building permits/Inhabitants  \
# Price in /m²                                        0.721368
# Material Costs                                       0.637347
# Employment costs                                     0.696985
# Inflation Rate                                      -0.015334
# Unemployment rate                                   -0.506178
# Participation at Stock Exchange                      0.245573
# GDP                                                -0.256043
# Money Supply                                        0.606029
# Key interest rate                                   -0.617343
# DAX                                                 0.700109
# Building permits/Inhabitants                         1.000000
# Volatility Index                                    -0.197642
#
#                                  Volatility Index
# Price in /m²                           -0.037554
# Material Costs                           0.026473
# Employment costs                         0.031243
# Inflation Rate                          -0.208213
# Unemployment rate                        0.015277
# Participation at Stock Exchange         -0.003146
# GDP                                     0.197078
# Money Supply                            0.115704
# Key interest rate                        0.071489
# DAX                                    -0.169176
# Building permits/Inhabitants            -0.197642
# Volatility Index                         1.000000

# %%
sns.heatmap(customers.corr())  #heatmap for correlation matrix
# Out:
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)
# <AxesSubplot:>

# %%
customers.describe() #descriptive statistics
# Out:
#        Price in /m²  Material Costs  Employment costs  Inflation Rate  \
# count      72.000000       72.000000         72.000000       72.000000
# mean     1797.986111       96.923611         97.606944        0.004064
# std       570.545982       10.437480         12.004264        0.004870
# min      1308.000000       76.900000         81.300000       -0.007500
# 25%      1361.500000       89.300000         87.125000        0.001075
# 50%      1534.000000       98.100000         96.200000        0.003900
# 75%      2101.000000      102.800000        106.525000        0.006725
# max      3353.000000      125.600000        122.900000        0.018900
#
#        Unemployment rate  Participation at Stock Exchange         GDP   \
# count          72.000000                        72.000000  7.200000e+01
# mean            0.063275                      7174.277778  1.148847e+12
# std             0.023403                      1007.839402  1.531289e+11
# min             0.030750                      5967.000000  8.800000e+11
# 25%             0.046375                      6120.000000  1.007500e+12
# 50%             0.057000                      7115.000000  1.165000e+12
# 75%             0.077187                      7947.000000  1.255000e+12
# max             0.112000                      9339.000000  1.530000e+12
#
#        Money Supply   Key interest rate         DAX   \
# count    7.200000e+01          72.000000     72.000000
# mean     2.589444e+12           0.011208   8642.137222
# std      5.702134e+11           0.013240   3233.829897
# min      1.640000e+12           0.000000   3858.880000
# 25%      2.320000e+12           0.000000   6002.590000
# 50%      2.455000e+12           0.007500   7817.675000
# 75%      2.960000e+12           0.022500  11381.370000
# max      3.750000e+12           0.042500  15563.890000
#
#        Building permits/Inhabitants  Volatility Index
# count                     72.000000         72.000000
# mean                   69430.555556         22.484028
# std                    22357.584190          7.576652
# min                    30625.000000         13.270000
# 25%                    51287.500000         17.195000
# 50%                    66475.000000         20.560000
# 75%                    86812.500000         25.437500
# max                   114300.000000         57.330000

# %%
pp=sns.pairplot(customers)   #pairplot of all variables
# Out:
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
customers.head(3)   #rechecking the variables
# Out:
#    Quartal  Price in /m²  Material Costs  Employment costs  Inflation Rate  \
# 0        1           1448            76.9              83.2          0.0055
# 1        2           1433            79.9              83.3          0.0055
# 2        3           1422            79.9              83.2          0.0011
#
#    Unemployment rate  Participation at Stock Exchange         GDP   \
# 0            0.10050                             7843  9.180000e+11
# 1            0.10300                             7843  8.940000e+11
# 2            0.10375                             7843  9.050000e+11
#
#    Money Supply   Key interest rate    DAX   Building permits/Inhabitants  \
# 0    1.640000e+12             0.0225  4018.51                         47075
# 1    1.640000e+12             0.0225  3950.01                         67250
# 2    1.640000e+12             0.0225  3858.88                         73975
#
#    Volatility Index
# 0             22.06
# 1             23.07
# 2             19.55

# %% [markdown]
# # Linear regression, Fitting and training the model

# %%
y = customers['Price in /m²']  #y variable assigned

# %%
X = customers[['Material Costs', 'Employment costs','Inflation Rate','Unemployment rate','Participation at Stock Exchange','GDP ','Money Supply ','Key interest rate','DAX ','Building permits/Inhabitants','Volatility Index']]     #x variables assigned

# %%
from sklearn.model_selection import train_test_split  #importing scikit (python library) learn for machine learning

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)  #splitting train and test data

# %%
from sklearn.linear_model import LinearRegression #importing linear algorithm

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train) #fitting the model
# Out:
# LinearRegression()

# %%
print('Coefficients: \n', lm.coef_)
# Out:
# Coefficients:
#  [-1.60720646e+00  4.85179004e+01  5.66352243e+02  6.98036046e+03
#   2.08535720e-02 -2.18613348e-10  9.32688104e-11  5.81019031e+03
#   2.26134008e-02  2.03708683e-03 -2.40879273e+00]

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df    #coefficients printed
# Out:
#                                   Coefficient
# Material Costs                  -1.607206e+00
# Employment costs                 4.851790e+01
# Inflation Rate                   5.663522e+02
# Unemployment rate                6.980360e+03
# Participation at Stock Exchange  2.085357e-02
# GDP                            -2.186133e-10
# Money Supply                    9.326881e-11
# Key interest rate                5.810190e+03
# DAX                             2.261340e-02
# Building permits/Inhabitants     2.037087e-03
# Volatility Index                -2.408793e+00

# %%
print(lm.intercept_)    #the intercept
# Out:
# -3714.5770498417733

# %%
predictions = lm.predict( X_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')  #graph of predictions vs actual values
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics       #printing the errors to measure model accuracy

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 64.11214536185112
# MSE: 5921.935550927238
# RMSE: 76.95411328140452

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
r2_score = regressor.score(X_test,y_test)
print(r2_score*100,'%')   #printing r squared value
# Out:
# 98.35171089532115 %

# %% [markdown]
# # Checking for highly correlated variables

# %%
plt.figure(figsize=(12,10)) #we check for correlated variables through a heatmap
cor=X_train.corr()
sns.heatmap(cor,annot=True,cmap=plt.cm.CMRmap_r)
plt.show()
# Out:
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
def correlation(dataset, threshold):
    col_corr = set()  # Set of all the names of correlated columns
    corr_matrix = dataset.corr()
    for i in range(len(corr_matrix.columns)):
        for j in range(i):
            if abs(corr_matrix.iloc[i, j]) > threshold: # we are interested in absolute coeff value
                colname = corr_matrix.columns[i]  # getting the name of column
                col_corr.add(colname)
    return col_corr

#we use this bit of code to identify variables with a certain level of correlation with each other

# %%
corr_features = correlation(X_train,0.90) #the threshold is set to 90 percent
len(set(corr_features))
# Out:
# 3

# %%
corr_features #name of the highly correlated variables
# Out:
# {'DAX \x80', 'Employment costs', 'Money Supply \x80'}

# %%
X_train=X_train.drop(corr_features,axis=1)
X_test= X_test.drop(corr_features,axis=1)  #we remove the variables now

# %%
X_train.head(5)
# Out:
#     Material Costs  Inflation Rate  Unemployment rate  \
# 11            86.2          0.0085            0.09400
# 3             79.9          0.0099            0.10600
# 54           103.4          0.0059            0.03700
# 45           100.4          0.0070            0.04675
# 10            85.4         -0.0010            0.09800
#
#     Participation at Stock Exchange         GDP   Key interest rate  \
# 11                             7948  9.890000e+11             0.0335
# 3                              7843  9.600000e+11             0.0225
# 54                             7168  1.090000e+12             0.0000
# 45                             6114  1.000000e+12             0.0005
# 10                             7948  9.600000e+11             0.0300
#
#     Building permits/Inhabitants  Volatility Index
# 11                         74400             15.27
# 3                          80700             16.97
# 54                         95700             15.11
# 45                         78250             24.07
# 10                         68200             19.53

# %%
X_test.head(5)
# Out:
#     Material Costs  Inflation Rate  Unemployment rate  \
# 26            92.5           0.002            0.06725
# 27            93.5           0.008            0.06500
# 48            99.4           0.003            0.04325
# 22            89.3          -0.001            0.07775
# 30            96.6           0.005            0.05525
#
#     Participation at Stock Exchange         GDP   Key interest rate  \
# 26                             6036  1.210000e+12             0.0100
# 27                             6036  1.280000e+12             0.0125
# 48                             6332  9.590000e+11             0.0000
# 22                             6592  1.270000e+12             0.0125
# 30                             6120  1.350000e+12             0.0125
#
#     Building permits/Inhabitants  Volatility Index
# 26                         51700             23.36
# 27                         56400             20.34
# 48                         65625             29.42
# 22                         48950             29.43
# 30                         62700             33.73

# %%
lm = LinearRegression() #we fit the model again, train and test the data to get coefficients, intercepts and errors

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Coefficients: \n', lm.coef_)
# Out:
# Coefficients:
#  [ 3.69137623e+01  1.82892840e+03  5.97594243e+02  2.37910103e-01
#  -2.47181817e-10 -8.23982361e+03  1.86844346e-03  1.07510131e+00]

# %%
print(lm.intercept_)
# Out:
# -3299.390773686686

# %%
predictions = lm.predict( X_test) #graph of test vs actual values

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics #error calculation

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 83.85636961953271
# MSE: 12066.063178160895
# RMSE: 109.84563340506939

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
r2_score = regressor.score(X_test,y_test)
print(r2_score*100,'%')  #R squared value
# Out:
# 96.64157768994713 %

# %% [markdown]
# # Mutual information selection feature setting

# %%
from sklearn.feature_selection import mutual_info_regression
# determine the mutual information
mutual_info = mutual_info_regression(X_train.fillna(0), y_train)
mutual_info     #we sort variables on the basis of their mutual information values
# Out:
# array([1.37648234, 0.15039096, 1.2831637 , 0.80875643, 0.48314458,
#        0.82154325, 0.42493304, 0.11094723])

# %%
mutual_info = pd.Series(mutual_info)
mutual_info.index = X_train.columns
mutual_info.sort_values(ascending=False) # sorting values
# Out:
# Material Costs                     1.376482
# Unemployment rate                  1.283164
# Key interest rate                  0.821543
# Participation at Stock Exchange    0.808756
# GDP                               0.483145
# Building permits/Inhabitants       0.424933
# Inflation Rate                     0.150391
# Volatility Index                   0.110947
# dtype: float64

# %%
 mutual_info.sort_values(ascending=False).plot.bar(figsize=(15,5))  #visualizing values
# Out:
# <AxesSubplot:>
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
from sklearn.feature_selection import SelectPercentile  #selecting the top 80 percent of the features

# %%
## Selecting the top 20 percentile
selected_top_columns = SelectPercentile(mutual_info_regression, percentile=80)
selected_top_columns.fit(X_train.fillna(0), y_train)
# Out:
# SelectPercentile(percentile=80,
#                  score_func=<function mutual_info_regression at 0x0000021D86D579D0>)

# %%
selected_top_columns.get_support()
# Out:
# array([ True, False,  True,  True,  True,  True,  True, False])

# %%
X_train.columns[selected_top_columns.get_support()]
# Out:
# Index(['Material Costs', 'Unemployment rate',
#        'Participation at Stock Exchange', 'GDP ', 'Key interest rate',
#        'Building permits/Inhabitants'],
#       dtype='object')

# %%
X_train.head()
# Out:
#     Material Costs  Inflation Rate  Unemployment rate  \
# 11            86.2          0.0085            0.09400
# 3             79.9          0.0099            0.10600
# 54           103.4          0.0059            0.03700
# 45           100.4          0.0070            0.04675
# 10            85.4         -0.0010            0.09800
#
#     Participation at Stock Exchange         GDP   Key interest rate  \
# 11                             7948  9.890000e+11             0.0335
# 3                              7843  9.600000e+11             0.0225
# 54                             7168  1.090000e+12             0.0000
# 45                             6114  1.000000e+12             0.0005
# 10                             7948  9.600000e+11             0.0300
#
#     Building permits/Inhabitants  Volatility Index
# 11                         74400             15.27
# 3                          80700             16.97
# 54                         95700             15.11
# 45                         78250             24.07
# 10                         68200             19.53

# %%
#we remove volatility index and inflation rate

# %%
X_train=X_train.drop('Volatility Index',axis=1)
X_train=X_train.drop('Inflation Rate',axis=1)

# %%
X_test=X_test.drop('Volatility Index',axis=1)
X_test=X_test.drop('Inflation Rate',axis=1)

# %%
X_test.head(2)
# Out:
#     Material Costs  Unemployment rate  Participation at Stock Exchange  \
# 26            92.5            0.06725                             6036
# 27            93.5            0.06500                             6036
#
#            GDP   Key interest rate  Building permits/Inhabitants
# 26  1.210000e+12             0.0100                         51700
# 27  1.280000e+12             0.0125                         56400

# %%
X_train.head()
# Out:
#     Material Costs  Unemployment rate in %  Participation at Stock Exchange  \
# 11            86.2                 0.09400                             7948
# 3             79.9                 0.10600                             7843
# 54           103.4                 0.03700                             7168
# 45           100.4                 0.04675                             6114
# 10            85.4                 0.09800                             7948
#
#     GDP in Billion Dollar  Key interest rate in %  \
# 11           989389590200                  0.0335
# 3            959680272500                  0.0225
# 54          1089492578750                  0.0000
# 45          1003263792400                  0.0005
# 10           960154640500                  0.0300
#
#     Anzahl von Baugenehmigungen pro Einwohner in 1000 als proxy
# 11                                              74400
# 3                                               80700
# 54                                              95700
# 45                                              78250
# 10                                              68200

# %%
from sklearn.linear_model import LinearRegression  #do the regression again to get results

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Coefficients: \n', lm.coef_)
# Out:
# Coefficients:
#  [ 3.75858280e+01  7.41645648e+02  2.38582782e-01 -2.44573500e-10
#  -8.11929424e+03  1.68657706e-03]

# %%
predictions = lm.predict( X_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 81.54243876284959
# MSE: 11462.12251484074
# RMSE: 107.0613026020174

# %%
sns.distplot((y_test-predictions),bins=20)  #distribution plot to visualize the predicted values
# Out:
# C:\Users\Jarvis\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price in \x80/m²', ylabel='Density'>
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # END here

# %%
customers2 = pd.read_csv("C:/Users/Jarvis/Desktop/mt_data22.csv",encoding= 'unicode_escape')

# %%
customers2.head(5)
# Out:
#    Quartal  Year  Price in /m²  Material Costs  Employment costs  \
# 0        1  2004           1448            76.9              83.2
# 1        2  2004           1433            79.9              83.3
# 2        3  2004           1422            79.9              83.2
# 3        4  2004           1405            79.9              81.3
# 4        1  2005           1395            80.5              83.6
#
#    Inflation Rate  Unemployment rate  Participation at Stock Exchange  \
# 0          0.0055            0.10050                             7843
# 1          0.0055            0.10300                             7843
# 2          0.0011            0.10375                             7843
# 3          0.0099            0.10600                             7843
# 4          0.0012            0.10900                             8066
#
#           GDP   Money Supply   Key interest rate    DAX   \
# 0  9.180000e+11    1.640000e+12             0.0225  4018.51
# 1  8.940000e+11    1.640000e+12             0.0225  3950.01
# 2  9.050000e+11    1.640000e+12             0.0225  3858.88
# 3  9.600000e+11    1.640000e+12             0.0225  4079.26
# 4  1.000000e+12    1.770000e+12             0.0225  4309.37
#
#    Building permits/Inhabitants  Volatility Index
# 0                         47075             22.06
# 1                         67250             23.07
# 2                         73975             19.55
# 3                         80700             16.97
# 4                         42000             13.50

# %%
sns.jointplot(x='Price in /m²',y='Material Costs',data=customers2,hue='Year',palette='coolwarm')
# Out:
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.jointplot(x='GDP ',y='Price in /m²',data=customers2,hue='Year')
# Out:
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
sns.jointplot(x='Key interest rate',y='Price in /m²',data=customers2,hue='Year')
# Out:
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jarvis\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Jarvis\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Jarvis\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Jarvis\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Jarvis\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Jarvis\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Jarvis\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Jarvis\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Jarvis\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Jarvis\anaconda3\lib\site-packages\seaborn\distributions.py:305: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %%
lm = LinearRegression()
lm.fit(X_train,y_train)
print('Coefficients: \n', lm.coef_)
predictions = lm.predict( X_test)
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))

from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
r2_score = regressor.score(X_test,y_test)
print(r2_score*100,'%')

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Coefficients: \n', lm.coef_)
# Out:
# Coefficients:
#  [ 3.76664307e+01  7.63653798e+02  2.38351313e-01 -2.46543322e-10
#  -8.10022576e+03  1.68366335e-03]

# %%
predictions = lm.predict( X_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 81.58223648191874
# MSE: 11521.31886260398
# RMSE: 107.33740663256206

# %%
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train,y_train)
r2_score = regressor.score(X_test,y_test)
print(r2_score*100,'%')
# Out:
# 96.79319975885458 %

# %%
sns.distplot((y_test-predictions),bins=10)
# Out:
# C:\Users\Jarvis\anaconda3\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)
# <AxesSubplot:xlabel='Price in \x80/m²', ylabel='Density'>
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\Jarvis\anaconda3\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 128 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# # ending here

# %%
# Out:
# Feature 0: 11.062683
# Feature 1: 3.658726
# Feature 2: 6.056499
# Feature 3: 0.438893
# Feature 4: 17.281429
# Feature 5: 4.056207
# Feature 6: 2.848413
# Feature 7: 0.678655
# Feature 8: 4.639745
# Feature 9: 11.178183
# Feature 10: 14.594848

# %%
X = customers[['Material Costs', 'Employment costs', 'Unemployment rate in %','Participation at Stock Exchange','GDP in Billion Dollar','Money Supply M1, M2 & M3','Key interest rate in %','DAX in ','Anzahl von Baugenehmigungen pro Einwohner in 1000 als proxy','Volatilitätsindex']]

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=101)

# %%
from sklearn.linear_model import LinearRegression

# %%
lm = LinearRegression()

# %%
lm.fit(X_train,y_train)
# Out:
# LinearRegression()

# %%
print('Coefficients: \n', lm.coef_)
# Out:
# Coefficients:
#  [ 42.69712913 -32.29251094   0.21971605   3.11419682  -2.87208296]

# %%
predictions = lm.predict( X_test)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# Text(0, 0.5, 'Predicted Y')

# %%
from sklearn import metrics

print('MAE:', metrics.mean_absolute_error(y_test, predictions))
print('MSE:', metrics.mean_squared_error(y_test, predictions))
print('RMSE:', np.sqrt(metrics.mean_squared_error(y_test, predictions)))
# Out:
# MAE: 117.9667907362242
# MSE: 19183.85425308439
# RMSE: 138.50579140629605

# %%
coeff_df = pd.DataFrame(lm.coef_,X.columns,columns=['Coefficient'])
coeff_df
# Out:
#                                                     Coefficient
# Material Costs                                        42.697129
# Inflation in %                                       -32.292511
# Participation at Stock Exchange                        0.219716
# Anzahl von Baugenehmigungen pro Einwohner in 10...     3.114197
# Volatilitätsindex                                     -2.872083

# %%
from sklearn.datasets import make_regression
from sklearn.model_selection import train_test_split
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import f_regression
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error

# %%
# feature selection
def select_features(X_train, y_train, X_test):
	# configure to select a subset of features
	fs = SelectKBest(score_func=f_regression, k=5)
	# learn relationship from training data
	fs.fit(X_train, y_train)
	# transform train input data
	X_train_fs = fs.transform(X_train)
	# transform test input data
	X_test_fs = fs.transform(X_test)
	return X_train_fs, X_test_fs, fs

# %%
# load the dataset
X, y = make_regression(n_samples=72, n_features=11, n_informative=10, noise=0.1, random_state=1)
# split into train and test sets
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=1)
# feature selection
X_train_fs, X_test_fs, fs = select_features(X_train, y_train, X_test)
# fit the model
model = LinearRegression()
model.fit(X_train_fs, y_train)
# evaluate the model
yhat = model.predict(X_test_fs)
# evaluate predictions
mae = mean_absolute_error(y_test, yhat)
print('MAE: %.3f' % mae)
# Out:
# MAE: 0.097

# %%
predictions = lm.predict( X_test_fs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-106-c3918d6b46a7> in <module>
# ----> 1 predictions = lm.predict( X_test_fs)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in predict(self, X)
#     234             Returns predicted values.
#     235         """
# --> 236         return self._decision_function(X)
#     237
#     238     _preprocess_data = staticmethod(_preprocess_data)
#
# ~\anaconda3\lib\site-packages\sklearn\linear_model\_base.py in _decision_function(self, X)
#     217
#     218         X = check_array(X, accept_sparse=['csr', 'csc', 'coo'])
# --> 219         return safe_sparse_dot(X, self.coef_.T,
#     220                                dense_output=True) + self.intercept_
#     221
#
# ~\anaconda3\lib\site-packages\sklearn\utils\validation.py in inner_f(*args, **kwargs)
#      70                           FutureWarning)
#      71         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 72         return f(**kwargs)
#      73     return inner_f
#      74
#
# ~\anaconda3\lib\site-packages\sklearn\utils\extmath.py in safe_sparse_dot(a, b, dense_output)
#     151             ret = np.dot(a, b)
#     152     else:
# --> 153         ret = a @ b
#     154
#     155     if (sparse.issparse(a) and sparse.issparse(b)
#
# ValueError: matmul: Input operand 1 has a mismatch in its core dimension 0, with gufunc signature (n?,k),(k,m?)->(n?,m?) (size 5 is different from 11)

# %%
plt.scatter(y_test,predictions)
plt.xlabel('Y Test')
plt.ylabel('Predicted Y')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-100-9a732a38fba0> in <module>
# ----> 1 plt.scatter(y_test,predictions)
#       2 plt.xlabel('Y Test')
#       3 plt.ylabel('Predicted Y')
#
# ~\anaconda3\lib\site-packages\matplotlib\pyplot.py in scatter(x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, data, **kwargs)
#    2888         verts=cbook.deprecation._deprecated_parameter,
#    2889         edgecolors=None, *, plotnonfinite=False, data=None, **kwargs):
# -> 2890     __ret = gca().scatter(
#    2891         x, y, s=s, c=c, marker=marker, cmap=cmap, norm=norm,
#    2892         vmin=vmin, vmax=vmax, alpha=alpha, linewidths=linewidths,
#
# ~\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ~\anaconda3\lib\site-packages\matplotlib\cbook\deprecation.py in wrapper(*inner_args, **inner_kwargs)
#     409                          else deprecation_addendum,
#     410                 **kwargs)
# --> 411         return func(*inner_args, **inner_kwargs)
#     412
#     413     return wrapper
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_axes.py in scatter(self, x, y, s, c, marker, cmap, norm, vmin, vmax, alpha, linewidths, verts, edgecolors, plotnonfinite, **kwargs)
#    4439         y = np.ma.ravel(y)
#    4440         if x.size != y.size:
# -> 4441             raise ValueError("x and y must be the same size")
#    4442
#    4443         if s is None:
#
# ValueError: x and y must be the same size

# %%
print('MSE:', metrics.mean_squared_error(y_test, predictions))
# Out:
# MSE: 22017628.174990494
